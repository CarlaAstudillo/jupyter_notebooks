# %% [markdown]
# # Data Analysis on New Jersey School Internet Speeds
#
# In February 2018, New Jersey Department of Education released in its Performance Report 2016-17 data on tech readiness for each school. Raw dataset can be found [here](https://rc.doe.state.nj.us/ReportsDatabase.aspx?).
#
# ### [Click here to go straight to the analysis](#analysis)

# %%
import pandas as pd

# %%
filename = "raw_data/PerformanceReports.xlsx"

# %%
performance_report = pd.read_excel(filename, sheetname=None)

# %%
performance_report.keys()
# Out:
# [u'GraduationRates',
#  u'PostsecondaryEnrRates16mos',
#  u'StudentSuspensionRates',
#  u'Narrative',
#  u'ELALiteracyPerformanceByGrade',
#  u'APIBCourseworkPartPerf',
#  u'EnrollmentTrendsByGrade',
#  u'VisualAndPerformingArts',
#  u'PSAT-SAT-ACTPerformance',
#  u'DropoutRateTrends',
#  u'SchoolHeader',
#  u'AlternateAssessmentParticipatio',
#  u'ELAPerformanceTrends',
#  u'MathCourseParticipation',
#  u'StudentGrowth',
#  u'Biology',
#  u'StudentGrowthByPerformLevel',
#  u'TeachersAdminsOneYearRetention',
#  u'MathPerformanceTrends',
#  u'DaysAbsent',
#  u'IndustryValuedCredentialsEarned',
#  u'PSAT-SAT-ACTParticipation',
#  u'PreKAndK-FullDayHalfDay',
#  u'CTE_SLEParticipation',
#  u'MathPerformanceByGradeTest',
#  u'EnrollmentTrendsByStudentGroup',
#  u'ChronicAbsByGrade',
#  u'TeachersExperienceCertification',
#  u'APIBCoursesOffered',
#  u'ELALiteracyParticipationPerform',
#  u'WorldLanguagesCourseParticipati',
#  u'AccountabilityIndicator',
#  u'StudentGrowthByGrade',
#  u'GraduationRateTrends',
#  u'ScienceCourseParticipation',
#  u'EnglishLanguageProficiencyTest',
#  u'MathParticipationPerform',
#  u'SchoolDay',
#  u'AdministratorsExperience',
#  u'ViolenceVandalismHIBSubstanceOf',
#  u'StudentExpulsions',
#  u'EnrollmentByHomeLanguage',
#  u'FacultyAttendance',
#  u'PerPupilExpenditures',
#  u'ChronicAbsenteeism',
#  u'EnrollmentByRacialEthnicGroup',
#  u'NJASKScience',
#  u'SocStudiesHistoryCourseParticip',
#  u'StudentToStaffRatios',
#  u'PostsecondaryEnrRatesFall',
#  u'TeachersAdminsLevelOfEducation',
#  u'TechnologyReadiness',
#  u'AccountabilitySummary',
#  u'EnrollmentTrendsFullSharedTime']

# %%
school_headers = performance_report['SchoolHeader']

# %%
school_headers.head(5)
# Out:
#    County Code  District Code  School Code County Name  District Name  \
# 0            1             10           50    ATLANTIC   ABSECON CITY
# 1            1             10           60    ATLANTIC   ABSECON CITY
# 2            1            110           10    ATLANTIC  ATLANTIC CITY
# 3            1            110           30    ATLANTIC  ATLANTIC CITY
# 4            1            110           50    ATLANTIC  ATLANTIC CITY
#
#                  School Name Grade Span
# 0             Emma C Attales      05-08
# 1             H Ashton Marsh      PK-04
# 2  Atlantic City High School      09-12
# 3    Sovereign Avenue School      PK-08
# 4     Chelsea Heights School      PK-08

# %%
tech_readiness = performance_report['TechnologyReadiness']

# %%
tech_readiness.head(5)
# Out:
#    CountyCode  DistrictCode  SchoolCode StudentDeviceRation InternetSpeed  \
# 0           1            10          50               1:1.3    120.0 kbps
# 1           1            10          60               1:0.4    120.0 kbps
# 2           1           110          10               1:1.3     71.4 kbps
# 3           1           110          30               1:0.9     71.4 kbps
# 4           1           110          50               1:1.3     71.4 kbps
#
#   RecommendedInternetSpeed MetRecommendedSpeed ConnectivityBetweenSchools  \
# 0                 100 kbps                 Yes                          N
# 1                 100 kbps                 Yes                          N
# 2                 100 kbps                  No                          N
# 3                 100 kbps                  No                          N
# 4                 100 kbps                  No                          N
#
#   RecommendedConnectivity MetRecommendedConnectivity
# 0                   Fiber                         No
# 1                   Fiber                         No
# 2                   Fiber                         No
# 3                   Fiber                         No
# 4                   Fiber                         No

# %%
len(school_headers.index)
# Out:
# 2516

# %%
len(tech_readiness.index)
# Out:
# 2236

# %%
list(school_headers.columns)
# Out:
# [u'County Code',
#  u'District Code',
#  u'School Code',
#  u'County Name',
#  u'District Name',
#  u'School Name',
#  u'Grade Span']

# %%
list(tech_readiness.columns)
# Out:
# [u'CountyCode',
#  u'DistrictCode',
#  u'SchoolCode',
#  u'StudentDeviceRation',
#  u'InternetSpeed',
#  u'RecommendedInternetSpeed',
#  u'MetRecommendedSpeed',
#  u'ConnectivityBetweenSchools',
#  u'RecommendedConnectivity',
#  u'MetRecommendedConnectivity']

# %%
merge_schools_tech =  pd.merge(school_headers, tech_readiness, left_on=['County Code', 'District Code', 'School Code'], right_on=['CountyCode', 'DistrictCode', 'SchoolCode'])

# %%
total_schools = len(merge_schools_tech.index)
len(merge_schools_tech.index)
# Out:
# 2236

# %%
merge_schools_tech.head(5)
# Out:
#    County Code  District Code  School Code County Name  District Name  \
# 0            1             10           50    ATLANTIC   ABSECON CITY
# 1            1             10           60    ATLANTIC   ABSECON CITY
# 2            1            110           10    ATLANTIC  ATLANTIC CITY
# 3            1            110           30    ATLANTIC  ATLANTIC CITY
# 4            1            110           50    ATLANTIC  ATLANTIC CITY
#
#                  School Name Grade Span  CountyCode  DistrictCode  SchoolCode  \
# 0             Emma C Attales      05-08           1            10          50
# 1             H Ashton Marsh      PK-04           1            10          60
# 2  Atlantic City High School      09-12           1           110          10
# 3    Sovereign Avenue School      PK-08           1           110          30
# 4     Chelsea Heights School      PK-08           1           110          50
#
#   StudentDeviceRation InternetSpeed RecommendedInternetSpeed  \
# 0               1:1.3    120.0 kbps                 100 kbps
# 1               1:0.4    120.0 kbps                 100 kbps
# 2               1:1.3     71.4 kbps                 100 kbps
# 3               1:0.9     71.4 kbps                 100 kbps
# 4               1:1.3     71.4 kbps                 100 kbps
#
#   MetRecommendedSpeed ConnectivityBetweenSchools RecommendedConnectivity  \
# 0                 Yes                          N                   Fiber
# 1                 Yes                          N                   Fiber
# 2                  No                          N                   Fiber
# 3                  No                          N                   Fiber
# 4                  No                          N                   Fiber
#
#   MetRecommendedConnectivity
# 0                         No
# 1                         No
# 2                         No
# 3                         No
# 4                         No

# %%
columns = ['CountyCode', 'DistrictCode', 'SchoolCode']
merge_schools_tech.drop(columns, inplace=True, axis=1)

# %%
merge_schools_tech.head(5)
# Out:
#    County Code  District Code  School Code County Name  District Name  \
# 0            1             10           50    ATLANTIC   ABSECON CITY
# 1            1             10           60    ATLANTIC   ABSECON CITY
# 2            1            110           10    ATLANTIC  ATLANTIC CITY
# 3            1            110           30    ATLANTIC  ATLANTIC CITY
# 4            1            110           50    ATLANTIC  ATLANTIC CITY
#
#                  School Name Grade Span StudentDeviceRation InternetSpeed  \
# 0             Emma C Attales      05-08               1:1.3    120.0 kbps
# 1             H Ashton Marsh      PK-04               1:0.4    120.0 kbps
# 2  Atlantic City High School      09-12               1:1.3     71.4 kbps
# 3    Sovereign Avenue School      PK-08               1:0.9     71.4 kbps
# 4     Chelsea Heights School      PK-08               1:1.3     71.4 kbps
#
#   RecommendedInternetSpeed MetRecommendedSpeed ConnectivityBetweenSchools  \
# 0                 100 kbps                 Yes                          N
# 1                 100 kbps                 Yes                          N
# 2                 100 kbps                  No                          N
# 3                 100 kbps                  No                          N
# 4                 100 kbps                  No                          N
#
#   RecommendedConnectivity MetRecommendedConnectivity
# 0                   Fiber                         No
# 1                   Fiber                         No
# 2                   Fiber                         No
# 3                   Fiber                         No
# 4                   Fiber                         No

# %%
merge_schools_tech.tail(5)
# Out:
#       County Code  District Code  School Code County Name  \
# 2231           80           8010          980    CHARTERS
# 2232           80           8050          990    CHARTERS
# 2233           80           8060          990    CHARTERS
# 2234           80           8065          980    CHARTERS
# 2235           80           8140          990    CHARTERS
#
#               District Name                             School Name  \
# 2231  Union County TEAMS CS       Union County TEAMS Charter School
# 2232               Unity CS                    Unity Charter School
# 2233  University Academy CS  University Academy Charter High School
# 2234  University Heights CS       University Heights Charter School
# 2235             Village CS              The Village Charter School
#
#      Grade Span StudentDeviceRation InternetSpeed RecommendedInternetSpeed  \
# 2231      KG-12               1:0.9    912.6 kbps                 100 kbps
# 2232      KG-08               1:0.9    319.1 kbps                 100 kbps
# 2233      09-12               1:1.1    238.7 kbps                 100 kbps
# 2234      PK-08               1:0.7   1422.5 kbps                 100 kbps
# 2235      KG-08               1:1.5    561.8 kbps                 100 kbps
#
#      MetRecommendedSpeed ConnectivityBetweenSchools RecommendedConnectivity  \
# 2231                 Yes                          N                   Fiber
# 2232                 Yes                          N                   Fiber
# 2233                 Yes                          N                   Fiber
# 2234                 Yes                          N                   Fiber
# 2235                 Yes                      Fiber                   Fiber
#
#      MetRecommendedConnectivity
# 2231                         No
# 2232                         No
# 2233                         No
# 2234                         No
# 2235                        Yes

# %%
unique_internet_speeds = merge_schools_tech["InternetSpeed"].unique()

# %%
merge_schools_tech.dtypes
# Out:
# County Code                    int64
# District Code                  int64
# School Code                    int64
# County Name                   object
# District Name                 object
# School Name                   object
# Grade Span                    object
# StudentDeviceRation           object
# InternetSpeed                 object
# RecommendedInternetSpeed      object
# MetRecommendedSpeed           object
# ConnectivityBetweenSchools    object
# RecommendedConnectivity       object
# MetRecommendedConnectivity    object
# dtype: object

# %%
#How many met recommended Internet Speed

recommended_speed = merge_schools_tech.groupby(["MetRecommendedSpeed"]).count()

recommended_speed = recommended_speed[['School Code']]

# %%
recommended_speed.reset_index()
# Out:
#   MetRecommendedSpeed  School Code
# 0                  No          442
# 1                 Yes         1794

# %%
recommended_speed['Percent'] = (recommended_speed['School Code']/total_schools)*100

# %%
recommended_speed = recommended_speed.reset_index()

# %%
recommended_speed
# Out:
#   MetRecommendedSpeed  School Code    Percent
# 0                  No          442  19.767442
# 1                 Yes         1794  80.232558

# %%
merge_schools_tech["InternetSpeed"] = merge_schools_tech["InternetSpeed"].str.rstrip(' kbps')

# %%
merge_schools_tech.dtypes
# Out:
# County Code                    int64
# District Code                  int64
# School Code                    int64
# County Name                   object
# District Name                 object
# School Name                   object
# Grade Span                    object
# StudentDeviceRation           object
# InternetSpeed                 object
# RecommendedInternetSpeed      object
# MetRecommendedSpeed           object
# ConnectivityBetweenSchools    object
# RecommendedConnectivity       object
# MetRecommendedConnectivity    object
# dtype: object

# %%
merge_schools_tech.head(5)
# Out:
#    County Code  District Code  School Code County Name  District Name  \
# 0            1             10           50    ATLANTIC   ABSECON CITY
# 1            1             10           60    ATLANTIC   ABSECON CITY
# 2            1            110           10    ATLANTIC  ATLANTIC CITY
# 3            1            110           30    ATLANTIC  ATLANTIC CITY
# 4            1            110           50    ATLANTIC  ATLANTIC CITY
#
#                  School Name Grade Span StudentDeviceRation InternetSpeed  \
# 0             Emma C Attales      05-08               1:1.3         120.0
# 1             H Ashton Marsh      PK-04               1:0.4         120.0
# 2  Atlantic City High School      09-12               1:1.3          71.4
# 3    Sovereign Avenue School      PK-08               1:0.9          71.4
# 4     Chelsea Heights School      PK-08               1:1.3          71.4
#
#   RecommendedInternetSpeed MetRecommendedSpeed ConnectivityBetweenSchools  \
# 0                 100 kbps                 Yes                          N
# 1                 100 kbps                 Yes                          N
# 2                 100 kbps                  No                          N
# 3                 100 kbps                  No                          N
# 4                 100 kbps                  No                          N
#
#   RecommendedConnectivity MetRecommendedConnectivity
# 0                   Fiber                         No
# 1                   Fiber                         No
# 2                   Fiber                         No
# 3                   Fiber                         No
# 4                   Fiber                         No

# %%
merge_schools_tech["InternetSpeed"] = pd.to_numeric(merge_schools_tech["InternetSpeed"], errors='coerce')

# %%
merge_schools_tech.dtypes
# Out:
# County Code                     int64
# District Code                   int64
# School Code                     int64
# County Name                    object
# District Name                  object
# School Name                    object
# Grade Span                     object
# StudentDeviceRation            object
# InternetSpeed                 float64
# RecommendedInternetSpeed       object
# MetRecommendedSpeed            object
# ConnectivityBetweenSchools     object
# RecommendedConnectivity        object
# MetRecommendedConnectivity     object
# dtype: object

# %%
merge_schools_tech = merge_schools_tech.sort_values('InternetSpeed')

# %%
merge_schools_tech.head(25)
# Out:
#       County Code  District Code  School Code County Name  \
# 275             3           4870           50      BERGEN
# 1939           37           1980           50      SUSSEX
# 126             3           1470           60      BERGEN
# 127             3           1470           80      BERGEN
# 2206           80           6665          930    CHARTERS
# 1829           31           5690           60     PASSAIC
# 1830           31           5690           70     PASSAIC
# 2211           80           6915          950    CHARTERS
# 109             3           1345           90      BERGEN
# 108             3           1345           80      BERGEN
# 107             3           1345           70      BERGEN
# 106             3           1345           60      BERGEN
# 105             3           1345           50      BERGEN
# 264             3           4470           50      BERGEN
# 208             3           3710           50      BERGEN
# 209             3           3710           60      BERGEN
# 421             5           5890           30  BURLINGTON
# 1788           31           4010          310     PASSAIC
# 1752           31           4010           20     PASSAIC
# 1787           31           4010          309     PASSAIC
# 1789           31           4010          311     PASSAIC
# 1784           31           4010          306     PASSAIC
# 1786           31           4010          308     PASSAIC
# 1754           31           4010           43     PASSAIC
# 1783           31           4010          305     PASSAIC
#
#                                District Name  \
# 275                     SOUTH HACKENSACK TWP
# 1939                             HAMPTON TWP
# 126                            FAIRVIEW BORO
# 127                            FAIRVIEW BORO
# 2206                                 Gray CS
# 1829                           WOODLAND PARK
# 1830                           WOODLAND PARK
# 2211  Jersey City Golden Door Charter School
# 109                             ELMWOOD PARK
# 108                             ELMWOOD PARK
# 107                             ELMWOOD PARK
# 106                             ELMWOOD PARK
# 105                             ELMWOOD PARK
# 264                        ROCHELLE PARK TWP
# 208                 NORTHERN VALLEY REGIONAL
# 209                 NORTHERN VALLEY REGIONAL
# 421                             WOODLAND TWP
# 1788                           PATERSON CITY
# 1752                           PATERSON CITY
# 1787                           PATERSON CITY
# 1789                           PATERSON CITY
# 1784                           PATERSON CITY
# 1786                           PATERSON CITY
# 1754                           PATERSON CITY
# 1783                           PATERSON CITY
#
#                                             School Name Grade Span  \
# 275                                     Memorial School      PK-08
# 1939                MARIAN E. MCKEOWN ELEMENTARY SCHOOL      KG-06
# 126                                      Lincoln School      04-08
# 127                                 Number Three School      KG-03
# 2206                            The Gray Charter School      KG-08
# 1829                            Beatrice Gilmore School      03-04
# 1830                             Memorial Middle School      05-08
# 2211             Jersey City Golden Door Charter School      PK-08
# 109                             Sixteenth Avenue School      PK-05
# 108                               Gilbert Avenue School      PK-05
# 107                               Gantner Avenue School      KG-05
# 106                              Memorial Middle School      06-08
# 105                         Memorial Senior High School      09-12
# 264                                   Midland School #1      PK-08
# 208    NORTHERN VALLEY REGIONAL HIGH SCHOOL AT DEMAREST      09-12
# 209   Northern Valley Regional High School at Old Ta...      09-12
# 421                        Chatsworth Elementary School      PK-08
# 1788                                          SCHOOL 28      PK-08
# 1752   Rosa L. Parks School of Fine and Performing Arts      09-12
# 1787                                          SCHOOL 16      PK-08
# 1789                                          SCHOOL 29      KG-04
# 1784                     SCHOOL OF BUISINESS TECHNOLOGY      09-12
# 1786                             GARRETT MORGAN ACADEMY      09-12
# 1754                         Alexander Hamilton Academy      KG-08
# 1783                   SCHOOL OF EDUCATION AND TRAINING      09-12
#
#      StudentDeviceRation  InternetSpeed RecommendedInternetSpeed  \
# 275                1:0.7            3.7                 100 kbps
# 1939               1:0.8            5.2                 100 kbps
# 126                1:0.4            7.0                 100 kbps
# 127                1:0.2            7.0                 100 kbps
# 2206               1:0.3            9.1                 100 kbps
# 1829                   N           15.4                 100 kbps
# 1830               1:0.3           15.4                 100 kbps
# 2211               1:0.2           19.1                 100 kbps
# 109                1:0.2           19.3                 100 kbps
# 108                1:0.3           19.3                 100 kbps
# 107                1:0.3           19.3                 100 kbps
# 106                1:1.2           19.3                 100 kbps
# 105                1:1.2           19.3                 100 kbps
# 264                1:0.6           20.0                 100 kbps
# 208                1:1.0           20.2                 100 kbps
# 209                1:0.8           20.2                 100 kbps
# 421                1:0.5           20.8                 100 kbps
# 1788               1:0.1           21.1                 100 kbps
# 1752               1:0.4           21.1                 100 kbps
# 1787               1:0.8           21.1                 100 kbps
# 1789               1:0.7           21.1                 100 kbps
# 1784               1:0.3           21.1                 100 kbps
# 1786               1:0.3           21.1                 100 kbps
# 1754               1:0.2           21.1                 100 kbps
# 1783               1:0.2           21.1                 100 kbps
#
#      MetRecommendedSpeed ConnectivityBetweenSchools RecommendedConnectivity  \
# 275                   No                          N                   Fiber
# 1939                  No                      Fiber                   Fiber
# 126                   No                   Wireless                   Fiber
# 127                   No                   Wireless                   Fiber
# 2206                  No                          N                   Fiber
# 1829                  No                          N                   Fiber
# 1830                  No                          N                   Fiber
# 2211                  No                          N                   Fiber
# 109                   No                          N                   Fiber
# 108                   No                          N                   Fiber
# 107                   No                          N                   Fiber
# 106                   No                          N                   Fiber
# 105                   No                          N                   Fiber
# 264                   No                   Wireless                   Fiber
# 208                   No                          N                   Fiber
# 209                   No                          N                   Fiber
# 421                   No                   Wireless                   Fiber
# 1788                  No                      Fiber                   Fiber
# 1752                  No                      Fiber                   Fiber
# 1787                  No                      Fiber                   Fiber
# 1789                  No                      Fiber                   Fiber
# 1784                  No                      Fiber                   Fiber
# 1786                  No                      Fiber                   Fiber
# 1754                  No                      Fiber                   Fiber
# 1783                  No                      Fiber                   Fiber
#
#      MetRecommendedConnectivity
# 275                          No
# 1939                        Yes
# 126                          No
# 127                          No
# 2206                         No
# 1829                         No
# 1830                         No
# 2211                         No
# 109                          No
# 108                          No
# 107                          No
# 106                          No
# 105                          No
# 264                          No
# 208                          No
# 209                          No
# 421                          No
# 1788                        Yes
# 1752                        Yes
# 1787                        Yes
# 1789                        Yes
# 1784                        Yes
# 1786                        Yes
# 1754                        Yes
# 1783                        Yes

# %%
slow_internet_schools = merge_schools_tech[(merge_schools_tech["InternetSpeed"] <= 100) | (merge_schools_tech["InternetSpeed"].isnull())  ]

# %%
len(slow_internet_schools.index)
# Out:
# 442

# %%
math_scores = performance_report['MathParticipationPerform']
ela_scores = performance_report['ELALiteracyParticipationPerform']

# %%
school_math_scores = math_scores[(math_scores["StudentGroup"] == "Schoolwide") ]
school_ela_scores = ela_scores[(ela_scores["StudentGroup"] == "Schoolwide") ]

# %%
print len(school_math_scores.index)
# Out:
# 2239

# %%
print len(school_ela_scores.index)
# Out:
# 2241

# %%
list(school_math_scores.columns)
# Out:
# [u'CountyCode',
#  u'DistrictCode',
#  u'SchoolCode',
#  u'StudentGroup',
#  u'Subject',
#  u'ValidScores',
#  u'ParticipationPercent',
#  u'SchoolPerformance',
#  u'DistrictPerformance',
#  u'StatePerformance',
#  u'ProfRateFederalAccountability',
#  u'AnnualTarget',
#  u'MetTarget']

# %%
slow_internet_schools1 =  pd.merge(slow_internet_schools, school_math_scores, left_on=['County Code', 'District Code', 'School Code'], right_on=['CountyCode', 'DistrictCode', 'SchoolCode'], how='left')

# %%
slow_internet_schools2 =  pd.merge(slow_internet_schools1, school_ela_scores, left_on=['County Code', 'District Code', 'School Code'], right_on=['CountyCode', 'DistrictCode', 'SchoolCode'], suffixes=('_Math', '_ELA'), how='left')

# %%
slow_internet_schools2.head(2)
# Out:
#    County Code  District Code  School Code County Name         District Name  \
# 0            3           4870           50      BERGEN  SOUTH HACKENSACK TWP
# 1           37           1980           50      SUSSEX           HAMPTON TWP
#
#                            School Name Grade Span StudentDeviceRation  \
# 0                      Memorial School      PK-08               1:0.7
# 1  MARIAN E. MCKEOWN ELEMENTARY SCHOOL      KG-06               1:0.8
#
#    InternetSpeed RecommendedInternetSpeed      ...      StudentGroup_ELA  \
# 0            3.7                 100 kbps      ...            Schoolwide
# 1            5.2                 100 kbps      ...            Schoolwide
#
#   Subject_ELA ValidScores_ELA ParticipationPercent_ELA  SchoolPerformance_ELA  \
# 0         LAL             149                     93.1                  73.10
# 1         LAL             155                     97.0                  68.40
#
#    DistrictPerformance_ELA  StatePerformance_ELA  \
# 0                    73.10                  54.9
# 1                    68.40                  54.9
#
#   ProfRateFederalAccountability_ELA AnnualTarget_ELA MetTarget_ELA
# 0                              71.3             65.8    Met Target
# 1                              68.4             72.8   Met Target†
#
# [2 rows x 40 columns]

# %%
race_data = performance_report['EnrollmentByRacialEthnicGroup']

# %%
race_data.head(10)
# Out:
#    CountyCode  DistrictCode  SchoolCode                 RacialAndEthnicGroup  \
# 0           1            10          50                                Asian
# 1           1            10          50            Black or African American
# 2           1            10          50                             Hispanic
# 3           1            10          50                    Two or More Races
# 4           1            10          50                                White
# 5           1            10          60                                Asian
# 6           1            10          60            Black or African American
# 7           1            10          60                             Hispanic
# 8           1            10          60  Native Hawaiian or Pacific Islander
# 9           1            10          60                    Two or More Races
#
#    Percent
# 0      0.8
# 1     16.7
# 2     10.3
# 3      9.2
# 4     63.1
# 5      7.2
# 6     14.4
# 7     14.0
# 8      0.4
# 9      5.1

# %%
asian_data = race_data[(race_data["RacialAndEthnicGroup"] == "Asian") ]
blk_data = race_data[(race_data["RacialAndEthnicGroup"] == "Black or African American") ]
hisp_data = race_data[(race_data["RacialAndEthnicGroup"] == "Hispanic") ]
white_data = race_data[(race_data["RacialAndEthnicGroup"] == "White") ]

# %%
slow_internet_schools_wwhite =  pd.merge(slow_internet_schools2, white_data, left_on=['County Code', 'District Code', 'School Code'], right_on=['CountyCode', 'DistrictCode', 'SchoolCode'], how='left', suffixes=('', '_white'))
slow_internet_schools_wblck =  pd.merge(slow_internet_schools_wwhite, blk_data, left_on=['County Code', 'District Code', 'School Code'], right_on=['CountyCode', 'DistrictCode', 'SchoolCode'], how='left', suffixes=('', '_blck'))
slow_internet_schools_whisp =  pd.merge(slow_internet_schools_wblck, hisp_data, left_on=['County Code', 'District Code', 'School Code'], right_on=['CountyCode', 'DistrictCode', 'SchoolCode'], how='left', suffixes=('', '_hisp'))
slow_internet_schools_wrace =  pd.merge(slow_internet_schools_whisp, asian_data, left_on=['County Code', 'District Code', 'School Code'], right_on=['CountyCode', 'DistrictCode', 'SchoolCode'], how='left', suffixes=('_x', '_asian'))

# %%
len(slow_internet_schools2.index)
# Out:
# 442

# %%
len(slow_internet_schools_wwhite.index)
# Out:
# 442

# %%
len(slow_internet_schools_wrace.index)
# Out:
# 442

# %%
cols_to_drop = ['CountyCode_Math', 'DistrictCode_Math', 'SchoolCode_Math', 'StudentGroup_Math', 'Subject_Math', 'CountyCode_ELA', 'DistrictCode_ELA', 'SchoolCode_ELA', 'StudentGroup_ELA', 'Subject_ELA', 'CountyCode_x', 'DistrictCode_x', 'SchoolCode_x','CountyCode_blck', 'DistrictCode_blck', 'SchoolCode_blck','CountyCode_hisp', 'DistrictCode_hisp', 'SchoolCode_hisp','CountyCode_asian', 'DistrictCode_asian', 'SchoolCode_asian']
slow_internet_schools_wrace2 = slow_internet_schools_wrace.drop(cols_to_drop, axis=1)

# %%
len(slow_internet_schools_wrace2.columns)
# Out:
# 38

# %%
slow_internet_schools_wrace2.rename(columns={'RacialAndEthnicGroup_x': 'RacialAndEthnicGroup_white', 'Percent_x': 'Percent_white'}, inplace=True)

# %%
slow_internet_schools_wrace2.head(5)
# Out:
#    County Code  District Code  School Code County Name         District Name  \
# 0            3           4870           50      BERGEN  SOUTH HACKENSACK TWP
# 1           37           1980           50      SUSSEX           HAMPTON TWP
# 2            3           1470           60      BERGEN         FAIRVIEW BORO
# 3            3           1470           80      BERGEN         FAIRVIEW BORO
# 4           80           6665          930    CHARTERS               Gray CS
#
#                            School Name Grade Span StudentDeviceRation  \
# 0                      Memorial School      PK-08               1:0.7
# 1  MARIAN E. MCKEOWN ELEMENTARY SCHOOL      KG-06               1:0.8
# 2                       Lincoln School      04-08               1:0.4
# 3                  Number Three School      KG-03               1:0.2
# 4              The Gray Charter School      KG-08               1:0.3
#
#    InternetSpeed RecommendedInternetSpeed      ...      AnnualTarget_ELA  \
# 0            3.7                 100 kbps      ...                  65.8
# 1            5.2                 100 kbps      ...                  72.8
# 2            7.0                 100 kbps      ...                  39.6
# 3            7.0                 100 kbps      ...                  36.2
# 4            9.1                 100 kbps      ...                  67.9
#
#   MetTarget_ELA RacialAndEthnicGroup_white Percent_white  \
# 0    Met Target                      White          27.7
# 1   Met Target†                      White          93.8
# 2    Met Target                      White          17.0
# 3   Met Target†                      White          12.1
# 4   Met Target†                      White           6.1
#
#    RacialAndEthnicGroup_blck Percent_blck RacialAndEthnicGroup_hisp  \
# 0  Black or African American          6.3                  Hispanic
# 1  Black or African American          1.0                  Hispanic
# 2  Black or African American          1.7                  Hispanic
# 3  Black or African American          1.3                  Hispanic
# 4  Black or African American         39.4                  Hispanic
#
#   Percent_hisp  RacialAndEthnicGroup_asian Percent_asian
# 0         57.6                       Asian           6.6
# 1          4.1                       Asian           0.7
# 2         79.4                       Asian           1.7
# 3         85.8                       Asian           0.6
# 4         50.3                       Asian           3.3
#
# [5 rows x 38 columns]

# %%
cols_to_drop = ['RacialAndEthnicGroup_blck', 'RacialAndEthnicGroup_white', 'RacialAndEthnicGroup_hisp', 'RacialAndEthnicGroup_asian']
slow_internet_schools_wrace3 = slow_internet_schools_wrace2.drop(cols_to_drop, axis=1)

# %%
list(slow_internet_schools_wrace3.columns)
# Out:
# [u'County Code',
#  u'District Code',
#  u'School Code',
#  u'County Name',
#  u'District Name',
#  u'School Name',
#  u'Grade Span',
#  u'StudentDeviceRation',
#  u'InternetSpeed',
#  u'RecommendedInternetSpeed',
#  u'MetRecommendedSpeed',
#  u'ConnectivityBetweenSchools',
#  u'RecommendedConnectivity',
#  u'MetRecommendedConnectivity',
#  u'ValidScores_Math',
#  u'ParticipationPercent_Math',
#  u'SchoolPerformance_Math',
#  u'DistrictPerformance_Math',
#  u'StatePerformance_Math',
#  u'ProfRateFederalAccountability_Math',
#  u'AnnualTarget_Math',
#  u'MetTarget_Math',
#  u'ValidScores_ELA',
#  u'ParticipationPercent_ELA',
#  u'SchoolPerformance_ELA',
#  u'DistrictPerformance_ELA',
#  u'StatePerformance_ELA',
#  u'ProfRateFederalAccountability_ELA',
#  u'AnnualTarget_ELA',
#  u'MetTarget_ELA',
#  'Percent_white',
#  u'Percent_blck',
#  u'Percent_hisp',
#  u'Percent_asian']

# %%
slow_internet_schools_wrace3
# Out:
#      County Code  District Code  School Code County Name  \
# 0              3           4870           50      BERGEN
# 1             37           1980           50      SUSSEX
# 2              3           1470           60      BERGEN
# 3              3           1470           80      BERGEN
# 4             80           6665          930    CHARTERS
# 5             31           5690           60     PASSAIC
# 6             31           5690           70     PASSAIC
# 7             80           6915          950    CHARTERS
# 8              3           1345           90      BERGEN
# 9              3           1345           80      BERGEN
# 10             3           1345           70      BERGEN
# 11             3           1345           60      BERGEN
# 12             3           1345           50      BERGEN
# 13             3           4470           50      BERGEN
# 14             3           3710           50      BERGEN
# 15             3           3710           60      BERGEN
# 16             5           5890           30  BURLINGTON
# 17            31           4010          310     PASSAIC
# 18            31           4010           20     PASSAIC
# 19            31           4010          309     PASSAIC
# 20            31           4010          311     PASSAIC
# 21            31           4010          306     PASSAIC
# 22            31           4010          308     PASSAIC
# 23            31           4010           43     PASSAIC
# 24            31           4010          305     PASSAIC
# 25            31           4010          325     PASSAIC
# 26            31           4010          316     PASSAIC
# 27            31           4010           47     PASSAIC
# 28            31           4010          315     PASSAIC
# 29            31           4010           50     PASSAIC
# ..           ...            ...          ...         ...
# 412           31            900          100     PASSAIC
# 413           31            900          200     PASSAIC
# 414           31            900          120     PASSAIC
# 415           31            900          110     PASSAIC
# 416           80           6020          985    CHARTERS
# 417           37           5360           25      SUSSEX
# 418           37           5360           20      SUSSEX
# 419           37           5360           23      SUSSEX
# 420           37           5360           40      SUSSEX
# 421           37           5360           30      SUSSEX
# 422           31           1920           15     PASSAIC
# 423           23           3530          300   MIDDLESEX
# 424           23           3530          125   MIDDLESEX
# 425           23           3530          123   MIDDLESEX
# 426           23           3530          100   MIDDLESEX
# 427           23           3530           90   MIDDLESEX
# 428           23           3530           80   MIDDLESEX
# 429           23           3530           60   MIDDLESEX
# 430           23           3530           55   MIDDLESEX
# 431           23           3530           50   MIDDLESEX
# 432           23           3530          140   MIDDLESEX
# 433           23           3530          110   MIDDLESEX
# 434           80           6017          932    CHARTERS
# 435            7           1799          111      CAMDEN
# 436            7           1801          113      CAMDEN
# 437           80           6060          942    CHARTERS
# 438           80           6101          992    CHARTERS
# 439           80           6104          995    CHARTERS
# 440           80           6107          998    CHARTERS
# 441           80           6183          914    CHARTERS
#
#                                          District Name  \
# 0                                 SOUTH HACKENSACK TWP
# 1                                          HAMPTON TWP
# 2                                        FAIRVIEW BORO
# 3                                        FAIRVIEW BORO
# 4                                              Gray CS
# 5                                        WOODLAND PARK
# 6                                        WOODLAND PARK
# 7               Jersey City Golden Door Charter School
# 8                                         ELMWOOD PARK
# 9                                         ELMWOOD PARK
# 10                                        ELMWOOD PARK
# 11                                        ELMWOOD PARK
# 12                                        ELMWOOD PARK
# 13                                   ROCHELLE PARK TWP
# 14                            NORTHERN VALLEY REGIONAL
# 15                            NORTHERN VALLEY REGIONAL
# 16                                        WOODLAND TWP
# 17                                       PATERSON CITY
# 18                                       PATERSON CITY
# 19                                       PATERSON CITY
# 20                                       PATERSON CITY
# 21                                       PATERSON CITY
# 22                                       PATERSON CITY
# 23                                       PATERSON CITY
# 24                                       PATERSON CITY
# 25                                       PATERSON CITY
# 26                                       PATERSON CITY
# 27                                       PATERSON CITY
# 28                                       PATERSON CITY
# 29                                       PATERSON CITY
# ..                                                 ...
# 412                                       CLIFTON CITY
# 413                                       CLIFTON CITY
# 414                                       CLIFTON CITY
# 415                                       CLIFTON CITY
# 416                       Pride Academy Charter School
# 417                                         VERNON TWP
# 418                                         VERNON TWP
# 419                                         VERNON TWP
# 420                                         VERNON TWP
# 421                                         VERNON TWP
# 422                                       HALEDON BORO
# 423                                 NEW BRUNSWICK CITY
# 424                                 NEW BRUNSWICK CITY
# 425                                 NEW BRUNSWICK CITY
# 426                                 NEW BRUNSWICK CITY
# 427                                 NEW BRUNSWICK CITY
# 428                                 NEW BRUNSWICK CITY
# 429                                 NEW BRUNSWICK CITY
# 430                                 NEW BRUNSWICK CITY
# 431                                 NEW BRUNSWICK CITY
# 432                                 NEW BRUNSWICK CITY
# 433                                 NEW BRUNSWICK CITY
# 434                              Foundation Academy CS
# 435  KIPP: Cooper Norcross, A New Jersey Nonprofit ...
# 436                                  Camden Prep, Inc.
# 437                  Atlantic Community Charter School
# 438             College Achieve Central Charter School
# 439  International Academy of Atlantic City Charter...
# 440                    Camden’s Promise Charter School
# 441                          Trenton Stem-to-Civics CS
#
#                                            School Name Grade Span  \
# 0                                      Memorial School      PK-08
# 1                  MARIAN E. MCKEOWN ELEMENTARY SCHOOL      KG-06
# 2                                       Lincoln School      04-08
# 3                                  Number Three School      KG-03
# 4                              The Gray Charter School      KG-08
# 5                              Beatrice Gilmore School      03-04
# 6                               Memorial Middle School      05-08
# 7               Jersey City Golden Door Charter School      PK-08
# 8                              Sixteenth Avenue School      PK-05
# 9                                Gilbert Avenue School      PK-05
# 10                               Gantner Avenue School      KG-05
# 11                              Memorial Middle School      06-08
# 12                         Memorial Senior High School      09-12
# 13                                   Midland School #1      PK-08
# 14    NORTHERN VALLEY REGIONAL HIGH SCHOOL AT DEMAREST      09-12
# 15   Northern Valley Regional High School at Old Ta...      09-12
# 16                        Chatsworth Elementary School      PK-08
# 17                                           SCHOOL 28      PK-08
# 18    Rosa L. Parks School of Fine and Performing Arts      09-12
# 19                                           SCHOOL 16      PK-08
# 20                                           SCHOOL 29      KG-04
# 21                      SCHOOL OF BUISINESS TECHNOLOGY      09-12
# 22                              GARRETT MORGAN ACADEMY      09-12
# 23                          Alexander Hamilton Academy      KG-08
# 24                    SCHOOL OF EDUCATION AND TRAINING      09-12
# 25                                       NORMAN S WEIR      KG-08
# 26                                NEW ROBERTO CLEMENTE      06-08
# 27                                 EDWARD W KILPATRICK      PK-03
# 28                                    ROBERTO CLEMENTE      KG-05
# 29                                            SCHOOL 1      PK-05
# ..                                                 ...        ...
# 412                                          School #3      KG-05
# 413                                         School #15      PK-05
# 414                                          School #5      KG-05
# 415                                          School #4      KG-05
# 416                       Pride Academy Charter School      05-08
# 417                          Glen Meadow Middle School      07-08
# 418                        Vernon Township High School      09-12
# 419                      Cedar Mountain Primary School      02-04
# 420                       Rolling Hills Primary School      02-04
# 421                    Lounsberry Hollow Middle School      05-06
# 422                              Haledon Public School      PK-08
# 423                               LINCOLN ANNEX SCHOOL      03-08
# 424                        Roosevelt Elementary School      PK-05
# 425         Paul Robeson Community School for the Arts      PK-06
# 426                    Lord Stlrling Elementary School      PK-05
# 427                       Livingston Elementary School      KG-05
# 428                          Lincoln Elementary School      PK-05
# 429                           A Chester Redshaw School      PK-05
# 430                        New Brunswick Middle School      06-08
# 431                          New Brunswick High School      PK-12
# 432                   Woodrow Wilson Elementary School      PK-08
# 433                          Mckinley Community School      PK-08
# 434                  Foundation Academy Charter School      KG-12
# 435  KIPP: Cooper Norcross, A New Jersey Nonprofit ...      KG-08
# 436                                  Camden Prep, Inc.      KG-05
# 437                  Atlantic Community Charter School      KG-06
# 438             College Achieve Central Charter School      KG-07
# 439  International Academy of Atlantic City Charter...      KG-04
# 440                    Camden's Promise Charter School      KG-12
# 441              Trenton Stem-to-Civics Charter School      09-11
#
#     StudentDeviceRation  InternetSpeed RecommendedInternetSpeed      ...       \
# 0                 1:0.7            3.7                 100 kbps      ...
# 1                 1:0.8            5.2                 100 kbps      ...
# 2                 1:0.4            7.0                 100 kbps      ...
# 3                 1:0.2            7.0                 100 kbps      ...
# 4                 1:0.3            9.1                 100 kbps      ...
# 5                     N           15.4                 100 kbps      ...
# 6                 1:0.3           15.4                 100 kbps      ...
# 7                 1:0.2           19.1                 100 kbps      ...
# 8                 1:0.2           19.3                 100 kbps      ...
# 9                 1:0.3           19.3                 100 kbps      ...
# 10                1:0.3           19.3                 100 kbps      ...
# 11                1:1.2           19.3                 100 kbps      ...
# 12                1:1.2           19.3                 100 kbps      ...
# 13                1:0.6           20.0                 100 kbps      ...
# 14                1:1.0           20.2                 100 kbps      ...
# 15                1:0.8           20.2                 100 kbps      ...
# 16                1:0.5           20.8                 100 kbps      ...
# 17                1:0.1           21.1                 100 kbps      ...
# 18                1:0.4           21.1                 100 kbps      ...
# 19                1:0.8           21.1                 100 kbps      ...
# 20                1:0.7           21.1                 100 kbps      ...
# 21                1:0.3           21.1                 100 kbps      ...
# 22                1:0.3           21.1                 100 kbps      ...
# 23                1:0.2           21.1                 100 kbps      ...
# 24                1:0.2           21.1                 100 kbps      ...
# 25                1:0.4           21.1                 100 kbps      ...
# 26                1:0.5           21.1                 100 kbps      ...
# 27                1:0.1           21.1                 100 kbps      ...
# 28                1:0.3           21.1                 100 kbps      ...
# 29                1:0.2           21.1                 100 kbps      ...
# ..                  ...            ...                      ...      ...
# 412               1:0.3           92.1                 100 kbps      ...
# 413               1:0.3           92.1                 100 kbps      ...
# 414               1:0.4           92.1                 100 kbps      ...
# 415               1:0.4           92.1                 100 kbps      ...
# 416               1:0.7           94.1                 100 kbps      ...
# 417               1:1.5           94.9                 100 kbps      ...
# 418               1:1.2           94.9                 100 kbps      ...
# 419               1:0.5           94.9                 100 kbps      ...
# 420               1:0.9           94.9                 100 kbps      ...
# 421               1:1.1           94.9                 100 kbps      ...
# 422               1:0.3           95.3                 100 kbps      ...
# 423               1:1.1           98.0                 100 kbps      ...
# 424               1:0.6           98.0                 100 kbps      ...
# 425               1:0.5           98.0                 100 kbps      ...
# 426               1:0.7           98.0                 100 kbps      ...
# 427               1:0.5           98.0                 100 kbps      ...
# 428               1:0.6           98.0                 100 kbps      ...
# 429               1:0.5           98.0                 100 kbps      ...
# 430               1:1.3           98.0                 100 kbps      ...
# 431               1:0.9           98.0                 100 kbps      ...
# 432               1:0.7           98.0                 100 kbps      ...
# 433               1:0.9           98.0                 100 kbps      ...
# 434               1:0.1           99.8                 100 kbps      ...
# 435                   N            NaN                 100 kbps      ...
# 436                   N            NaN                 100 kbps      ...
# 437               1:0.6            NaN                 100 kbps      ...
# 438                   N            NaN                 100 kbps      ...
# 439                   N            NaN                 100 kbps      ...
# 440                   N            NaN                 100 kbps      ...
# 441                   N            NaN                 100 kbps      ...
#
#     SchoolPerformance_ELA DistrictPerformance_ELA StatePerformance_ELA  \
# 0                   73.10                   73.10                 54.9
# 1                   68.40                   68.40                 54.9
# 2                   42.60                   40.70                 54.9
# 3                   30.50                   40.70                 54.9
# 4                   77.60                   77.60                 54.9
# 5                   43.10                   47.80                 54.9
# 6                   49.80                   47.80                 54.9
# 7                   55.40                   55.40                 54.9
# 8                   51.80                   53.10                 54.9
# 9                   60.30                   53.10                 54.9
# 10                  67.90                   53.10                 54.9
# 11                  51.00                   53.10                 54.9
# 12                  45.60                   53.10                 54.9
# 13                  58.40                   58.40                 54.9
# 14                  70.00                   72.10                 54.9
# 15                  73.80                   72.10                 54.9
# 16                  40.90                   40.90                 54.9
# 17                  96.20                   26.40                 54.9
# 18                  40.80                   26.40                 54.9
# 19                  31.10                   26.40                 54.9
# 20                  37.30                   26.40                 54.9
# 21                      *                   26.40                 54.9
# 22                  19.50                   26.40                 54.9
# 23                  62.00                   26.40                 54.9
# 24                      *                   26.40                 54.9
# 25                  51.30                   26.40                 54.9
# 26                  24.90                   26.40                 54.9
# 27                      *                   26.40                 54.9
# 28                  40.40                   26.40                 54.9
# 29                  57.40                   26.40                 54.9
# ..                    ...                     ...                  ...
# 412                 60.50                   45.40                 54.9
# 413                 52.00                   45.40                 54.9
# 414                 51.60                   45.40                 54.9
# 415                 36.40                   45.40                 54.9
# 416                 63.10                   63.10                 54.9
# 417                 60.00                   59.10                 54.9
# 418                 63.80                   59.10                 54.9
# 419                 52.50                   59.10                 54.9
# 420                 55.80                   59.10                 54.9
# 421                 58.30                   59.10                 54.9
# 422                 53.60                   53.60                 54.9
# 423                 19.60                   26.00                 54.9
# 424                 19.90                   26.00                 54.9
# 425                 38.50                   26.00                 54.9
# 426                 20.40                   26.00                 54.9
# 427                 25.30                   26.00                 54.9
# 428                 92.90                   26.00                 54.9
# 429                 21.20                   26.00                 54.9
# 430                 21.70                   26.00                 54.9
# 431                 31.20                   26.00                 54.9
# 432                 43.30                   26.00                 54.9
# 433                 25.90                   26.00                 54.9
# 434                 52.70                   52.70                 54.9
# 435                 37.40                   37.40                 54.9
# 436                 34.70                   34.70                 54.9
# 437                 22.90                   22.90                 54.9
# 438                 34.30                   34.30                 54.9
# 439                 26.00                   26.00                 54.9
# 440                 49.10                   49.10                 54.9
# 441                 20.80                   20.80                 54.9
#
#     ProfRateFederalAccountability_ELA AnnualTarget_ELA MetTarget_ELA  \
# 0                                71.3             65.8    Met Target
# 1                                68.4             72.8   Met Target†
# 2                                42.6             39.6    Met Target
# 3                                30.5             36.2   Met Target†
# 4                                67.4             67.9   Met Target†
# 5                                43.1             39.6    Met Target
# 6                                49.8             49.5    Met Target
# 7                                55.4             48.9    Met Target
# 8                                51.8             47.2    Met Target
# 9                                60.3               59    Met Target
# 10                               66.1             52.9    Met Target
# 11                                 51               55       Not Met
# 12                               45.6             59.1       Not Met
# 13                               58.4             58.8   Met Target†
# 14                                 70             66.8    Met Target
# 15                               73.8             65.7    Met Target
# 16                               40.9                N             N
# 17                               96.2               80      Met Goal
# 18                               40.8             45.7   Met Target†
# 19                               31.1                N             N
# 20                               37.3             36.7    Met Target
# 21                                  *              8.8   Met Target†
# 22                               19.5             19.7   Met Target†
# 23                                 62             61.7    Met Target
# 24                                  *             13.8       Not Met
# 25                               51.3             51.5   Met Target†
# 26                               24.9             26.5   Met Target†
# 27                                  *             10.3   Met Target†
# 28                               40.4             36.6    Met Target
# 29                               56.3             50.3    Met Target
# ..                                ...              ...           ...
# 412                              60.5             61.6   Met Target†
# 413                                52             59.1       Not Met
# 414                              51.6             49.4    Met Target
# 415                              36.4             34.2    Met Target
# 416                              63.1             65.9   Met Target†
# 417                                60             53.3    Met Target
# 418                              63.8             69.6       Not Met
# 419                              52.5             57.5   Met Target†
# 420                              55.8             49.1    Met Target
# 421                              58.3             59.5   Met Target†
# 422                              53.6             49.1    Met Target
# 423                              19.6                N             N
# 424                              19.9             19.4    Met Target
# 425                              38.5             28.8    Met Target
# 426                              20.4             16.3    Met Target
# 427                              25.3             31.1       Not Met
# 428                              92.9               11      Met Goal
# 429                              21.2             23.2   Met Target†
# 430                              21.7             25.8       Not Met
# 431                              31.2             31.6   Met Target†
# 432                              43.3             40.6    Met Target
# 433                              25.9             21.6    Met Target
# 434                              52.7             56.3   Met Target†
# 435                              37.4                N             N
# 436                              34.7                N             N
# 437                              22.2             26.5   Met Target†
# 438                              34.3                N             N
# 439                                26                N             N
# 440                              49.1                N             N
# 441                              20.8             35.8       Not Met
#
#     Percent_white Percent_blck  Percent_hisp Percent_asian
# 0            27.7          6.3          57.6           6.6
# 1            93.8          1.0           4.1           0.7
# 2            17.0          1.7          79.4           1.7
# 3            12.1          1.3          85.8           0.6
# 4             6.1         39.4          50.3           3.3
# 5            51.4          5.7          37.6           4.9
# 6            48.7          4.0          42.0           3.0
# 7             8.8         27.1          28.6          34.4
# 8            35.4         11.0          36.9          15.0
# 9            40.9         16.1          33.9           7.5
# 10           53.1          4.1          33.8           7.4
# 11           43.8         11.8          31.8          12.3
# 12           37.6         10.7          41.4          10.2
# 13           49.9          6.6          29.7          13.8
# 14           59.9          0.9           5.9          28.7
# 15           69.1          0.6           5.2          23.0
# 16           92.4          3.5           4.2           NaN
# 17            4.4         32.7          52.3          10.5
# 18            1.1         40.9          57.6           0.4
# 19            2.6          9.3          87.0           1.1
# 20            6.8          9.2          67.9          16.0
# 21            2.2         28.5          62.5           6.6
# 22            4.9         27.4          64.6           2.4
# 23            0.5         31.4          67.7           0.4
# 24            7.9         18.9          60.2          13.0
# 25            2.4         50.2          47.1           0.3
# 26            0.5         13.6          85.2           0.7
# 27            2.3         40.5          56.5           0.8
# 28            0.3         14.1          85.6           NaN
# 29            1.8         49.3          48.6           0.4
# ..            ...          ...           ...           ...
# 412          35.4          2.0          57.8           4.4
# 413          18.3          5.4          71.3           4.0
# 414          39.7          2.7          49.1           7.7
# 415          42.9          4.6          48.6           4.0
# 416           NaN         96.2           3.8           NaN
# 417          83.4          3.8           9.2           2.3
# 418          85.9          2.6           9.4           0.9
# 419          82.4          2.2          11.1           2.2
# 420          84.1          1.2           9.1           2.1
# 421          84.4          2.1          10.2           1.7
# 422          21.1         13.3          58.4           7.0
# 423           0.2          3.0          96.1           0.5
# 424           0.5          3.3          96.1           0.1
# 425           0.2         10.4          89.0           NaN
# 426           NaN          7.5          91.8           0.3
# 427           NaN          7.5          91.7           0.9
# 428           0.8          2.8          94.7           1.4
# 429           0.5          6.1          92.8           0.1
# 430           0.1          6.6          92.4           0.6
# 431           0.8         12.4          86.4           0.4
# 432           8.3         19.9          69.9           1.5
# 433           0.3         25.5          73.4           0.3
# 434           0.9         54.4          43.8           0.5
# 435           1.4         57.5          32.8           0.1
# 436           1.5         79.9          18.6           NaN
# 437           1.4         88.5           9.1           0.7
# 438           1.0         28.0          69.8           0.3
# 439           1.0         59.2          39.8           NaN
# 440           NaN         22.2          77.2           0.4
# 441           0.3         64.3          35.0           0.3
#
# [442 rows x 34 columns]

# %%
enr_trends_bystudentgroup = performance_report['EnrollmentTrendsByStudentGroup']

# %%
enr_trends_bystudentgroup.head(5)
# Out:
#    CountyCode  DistrictCode  SchoolCode       StudentGroup  Percent
# 0           1            10          50         Disability      9.2
# 1           1            10          50            Econdis     36.7
# 2           1            10          50             Female     48.9
# 3           1            10          50  Homeless Students      0.6
# 4           1            10          50                LEP      2.2

# %%
school_econdis = enr_trends_bystudentgroup[(enr_trends_bystudentgroup["StudentGroup"] == "Econdis") ]
slow_internet_wecondis =  pd.merge(slow_internet_schools_wrace3, school_econdis, left_on=['County Code', 'District Code', 'School Code'], right_on=['CountyCode', 'DistrictCode', 'SchoolCode'], how="left")

# %%
len(school_econdis.index)
# Out:
# 2453

# %%
slow_internet_wecondis.head(5)
# Out:
#    County Code  District Code  School Code County Name         District Name  \
# 0            3           4870           50      BERGEN  SOUTH HACKENSACK TWP
# 1           37           1980           50      SUSSEX           HAMPTON TWP
# 2            3           1470           60      BERGEN         FAIRVIEW BORO
# 3            3           1470           80      BERGEN         FAIRVIEW BORO
# 4           80           6665          930    CHARTERS               Gray CS
#
#                            School Name Grade Span StudentDeviceRation  \
# 0                      Memorial School      PK-08               1:0.7
# 1  MARIAN E. MCKEOWN ELEMENTARY SCHOOL      KG-06               1:0.8
# 2                       Lincoln School      04-08               1:0.4
# 3                  Number Three School      KG-03               1:0.2
# 4              The Gray Charter School      KG-08               1:0.3
#
#    InternetSpeed RecommendedInternetSpeed   ...   MetTarget_ELA Percent_white  \
# 0            3.7                 100 kbps   ...      Met Target          27.7
# 1            5.2                 100 kbps   ...     Met Target†          93.8
# 2            7.0                 100 kbps   ...      Met Target          17.0
# 3            7.0                 100 kbps   ...     Met Target†          12.1
# 4            9.1                 100 kbps   ...     Met Target†           6.1
#
#   Percent_blck Percent_hisp Percent_asian CountyCode DistrictCode SchoolCode  \
# 0          6.3         57.6           6.6        3.0       4870.0       50.0
# 1          1.0          4.1           0.7       37.0       1980.0       50.0
# 2          1.7         79.4           1.7        3.0       1470.0       60.0
# 3          1.3         85.8           0.6        3.0       1470.0       80.0
# 4         39.4         50.3           3.3       80.0       6665.0      930.0
#
#    StudentGroup Percent
# 0       Econdis    38.4
# 1       Econdis    14.8
# 2       Econdis    72.2
# 3       Econdis    81.8
# 4       Econdis    78.8
#
# [5 rows x 39 columns]

# %%
cols_to_drop = ['CountyCode', 'DistrictCode', 'SchoolCode', 'StudentGroup']
slow_internet_schools_all_joins = slow_internet_wecondis.drop(cols_to_drop, axis=1)

# %%
slow_internet_schools_all_joins.rename(columns={'Percent': 'Percent_econdis'}, inplace=True)

# %%
slow_internet_schools_all_joins.head(5)
# Out:
#    County Code  District Code  School Code County Name         District Name  \
# 0            3           4870           50      BERGEN  SOUTH HACKENSACK TWP
# 1           37           1980           50      SUSSEX           HAMPTON TWP
# 2            3           1470           60      BERGEN         FAIRVIEW BORO
# 3            3           1470           80      BERGEN         FAIRVIEW BORO
# 4           80           6665          930    CHARTERS               Gray CS
#
#                            School Name Grade Span StudentDeviceRation  \
# 0                      Memorial School      PK-08               1:0.7
# 1  MARIAN E. MCKEOWN ELEMENTARY SCHOOL      KG-06               1:0.8
# 2                       Lincoln School      04-08               1:0.4
# 3                  Number Three School      KG-03               1:0.2
# 4              The Gray Charter School      KG-08               1:0.3
#
#    InternetSpeed RecommendedInternetSpeed       ...        \
# 0            3.7                 100 kbps       ...
# 1            5.2                 100 kbps       ...
# 2            7.0                 100 kbps       ...
# 3            7.0                 100 kbps       ...
# 4            9.1                 100 kbps       ...
#
#   DistrictPerformance_ELA StatePerformance_ELA  \
# 0                   73.10                 54.9
# 1                   68.40                 54.9
# 2                   40.70                 54.9
# 3                   40.70                 54.9
# 4                   77.60                 54.9
#
#   ProfRateFederalAccountability_ELA AnnualTarget_ELA MetTarget_ELA  \
# 0                              71.3             65.8    Met Target
# 1                              68.4             72.8   Met Target†
# 2                              42.6             39.6    Met Target
# 3                              30.5             36.2   Met Target†
# 4                              67.4             67.9   Met Target†
#
#   Percent_white Percent_blck Percent_hisp  Percent_asian Percent_econdis
# 0          27.7          6.3         57.6            6.6            38.4
# 1          93.8          1.0          4.1            0.7            14.8
# 2          17.0          1.7         79.4            1.7            72.2
# 3          12.1          1.3         85.8            0.6            81.8
# 4           6.1         39.4         50.3            3.3            78.8
#
# [5 rows x 35 columns]

# %% [markdown]
# <a id='analysis'></a>

# %%
slow_internet_schools_all_joins.to_csv('results/slow_internet_schools.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Analysis

# %%
slow_schools = len(slow_internet_schools_all_joins.index)

# %%
recommended_speed
# Out:
#   MetRecommendedSpeed  School Code    Percent
# 0                  No          442  19.767442
# 1                 Yes         1794  80.232558

# %% [markdown]
# According to the data, about **19.8%** or **442** of New Jersey schools are labeled as not meeting the state recommended Internet speed of 100 kbps– meaning they have internet speeds of less than 100 kbps. **Note:** there are about 7 schools which have their actual Internet speed as null but NJ DOE has labeled them as not having met the recommended Internet Speed.
#
# This is based on data on the **2,236** New Jersey schools that reported tech readiness results.

# %% [markdown]
# ### 25 Schools With Slowest Internet Speeds

# %%
merge_schools_tech.head(25)
# Out:
#       County Code  District Code  School Code County Name  \
# 275             3           4870           50      BERGEN
# 1939           37           1980           50      SUSSEX
# 126             3           1470           60      BERGEN
# 127             3           1470           80      BERGEN
# 2206           80           6665          930    CHARTERS
# 1829           31           5690           60     PASSAIC
# 1830           31           5690           70     PASSAIC
# 2211           80           6915          950    CHARTERS
# 109             3           1345           90      BERGEN
# 108             3           1345           80      BERGEN
# 107             3           1345           70      BERGEN
# 106             3           1345           60      BERGEN
# 105             3           1345           50      BERGEN
# 264             3           4470           50      BERGEN
# 208             3           3710           50      BERGEN
# 209             3           3710           60      BERGEN
# 421             5           5890           30  BURLINGTON
# 1788           31           4010          310     PASSAIC
# 1752           31           4010           20     PASSAIC
# 1787           31           4010          309     PASSAIC
# 1789           31           4010          311     PASSAIC
# 1784           31           4010          306     PASSAIC
# 1786           31           4010          308     PASSAIC
# 1754           31           4010           43     PASSAIC
# 1783           31           4010          305     PASSAIC
#
#                                District Name  \
# 275                     SOUTH HACKENSACK TWP
# 1939                             HAMPTON TWP
# 126                            FAIRVIEW BORO
# 127                            FAIRVIEW BORO
# 2206                                 Gray CS
# 1829                           WOODLAND PARK
# 1830                           WOODLAND PARK
# 2211  Jersey City Golden Door Charter School
# 109                             ELMWOOD PARK
# 108                             ELMWOOD PARK
# 107                             ELMWOOD PARK
# 106                             ELMWOOD PARK
# 105                             ELMWOOD PARK
# 264                        ROCHELLE PARK TWP
# 208                 NORTHERN VALLEY REGIONAL
# 209                 NORTHERN VALLEY REGIONAL
# 421                             WOODLAND TWP
# 1788                           PATERSON CITY
# 1752                           PATERSON CITY
# 1787                           PATERSON CITY
# 1789                           PATERSON CITY
# 1784                           PATERSON CITY
# 1786                           PATERSON CITY
# 1754                           PATERSON CITY
# 1783                           PATERSON CITY
#
#                                             School Name Grade Span  \
# 275                                     Memorial School      PK-08
# 1939                MARIAN E. MCKEOWN ELEMENTARY SCHOOL      KG-06
# 126                                      Lincoln School      04-08
# 127                                 Number Three School      KG-03
# 2206                            The Gray Charter School      KG-08
# 1829                            Beatrice Gilmore School      03-04
# 1830                             Memorial Middle School      05-08
# 2211             Jersey City Golden Door Charter School      PK-08
# 109                             Sixteenth Avenue School      PK-05
# 108                               Gilbert Avenue School      PK-05
# 107                               Gantner Avenue School      KG-05
# 106                              Memorial Middle School      06-08
# 105                         Memorial Senior High School      09-12
# 264                                   Midland School #1      PK-08
# 208    NORTHERN VALLEY REGIONAL HIGH SCHOOL AT DEMAREST      09-12
# 209   Northern Valley Regional High School at Old Ta...      09-12
# 421                        Chatsworth Elementary School      PK-08
# 1788                                          SCHOOL 28      PK-08
# 1752   Rosa L. Parks School of Fine and Performing Arts      09-12
# 1787                                          SCHOOL 16      PK-08
# 1789                                          SCHOOL 29      KG-04
# 1784                     SCHOOL OF BUISINESS TECHNOLOGY      09-12
# 1786                             GARRETT MORGAN ACADEMY      09-12
# 1754                         Alexander Hamilton Academy      KG-08
# 1783                   SCHOOL OF EDUCATION AND TRAINING      09-12
#
#      StudentDeviceRation  InternetSpeed RecommendedInternetSpeed  \
# 275                1:0.7            3.7                 100 kbps
# 1939               1:0.8            5.2                 100 kbps
# 126                1:0.4            7.0                 100 kbps
# 127                1:0.2            7.0                 100 kbps
# 2206               1:0.3            9.1                 100 kbps
# 1829                   N           15.4                 100 kbps
# 1830               1:0.3           15.4                 100 kbps
# 2211               1:0.2           19.1                 100 kbps
# 109                1:0.2           19.3                 100 kbps
# 108                1:0.3           19.3                 100 kbps
# 107                1:0.3           19.3                 100 kbps
# 106                1:1.2           19.3                 100 kbps
# 105                1:1.2           19.3                 100 kbps
# 264                1:0.6           20.0                 100 kbps
# 208                1:1.0           20.2                 100 kbps
# 209                1:0.8           20.2                 100 kbps
# 421                1:0.5           20.8                 100 kbps
# 1788               1:0.1           21.1                 100 kbps
# 1752               1:0.4           21.1                 100 kbps
# 1787               1:0.8           21.1                 100 kbps
# 1789               1:0.7           21.1                 100 kbps
# 1784               1:0.3           21.1                 100 kbps
# 1786               1:0.3           21.1                 100 kbps
# 1754               1:0.2           21.1                 100 kbps
# 1783               1:0.2           21.1                 100 kbps
#
#      MetRecommendedSpeed ConnectivityBetweenSchools RecommendedConnectivity  \
# 275                   No                          N                   Fiber
# 1939                  No                      Fiber                   Fiber
# 126                   No                   Wireless                   Fiber
# 127                   No                   Wireless                   Fiber
# 2206                  No                          N                   Fiber
# 1829                  No                          N                   Fiber
# 1830                  No                          N                   Fiber
# 2211                  No                          N                   Fiber
# 109                   No                          N                   Fiber
# 108                   No                          N                   Fiber
# 107                   No                          N                   Fiber
# 106                   No                          N                   Fiber
# 105                   No                          N                   Fiber
# 264                   No                   Wireless                   Fiber
# 208                   No                          N                   Fiber
# 209                   No                          N                   Fiber
# 421                   No                   Wireless                   Fiber
# 1788                  No                      Fiber                   Fiber
# 1752                  No                      Fiber                   Fiber
# 1787                  No                      Fiber                   Fiber
# 1789                  No                      Fiber                   Fiber
# 1784                  No                      Fiber                   Fiber
# 1786                  No                      Fiber                   Fiber
# 1754                  No                      Fiber                   Fiber
# 1783                  No                      Fiber                   Fiber
#
#      MetRecommendedConnectivity
# 275                          No
# 1939                        Yes
# 126                          No
# 127                          No
# 2206                         No
# 1829                         No
# 1830                         No
# 2211                         No
# 109                          No
# 108                          No
# 107                          No
# 106                          No
# 105                          No
# 264                          No
# 208                          No
# 209                          No
# 421                          No
# 1788                        Yes
# 1752                        Yes
# 1787                        Yes
# 1789                        Yes
# 1784                        Yes
# 1786                        Yes
# 1754                        Yes
# 1783                        Yes

# %% [markdown]
# ## How did these Schools Score in Math?

# %%
slow_internet_schools_all_joins['MetTarget_Math'].unique()
# Out:
# array([u'Met Target', u'Met Target\u2020', u'Not Met', u'N', u'Met Goal',
#        u'**', nan], dtype=object)

# %%
met_target_math = slow_internet_schools_all_joins.groupby( [ "MetTarget_Math"] ).count()

# %%
met_target_math = met_target_math[['School Code']]
met_target_math.reset_index()
met_target_math['Percent'] = (met_target_math['School Code']/slow_schools)*100
met_target_math.reset_index()
# Out:
#   MetTarget_Math  School Code    Percent
# 0             **            2   0.452489
# 1       Met Goal            5   1.131222
# 2     Met Target          165  37.330317
# 3    Met Target†          126  28.506787
# 4              N           12   2.714932
# 5        Not Met          131  29.638009

# %% [markdown]
# Out all of these 442 schools with less than 100 kpbs internet speeds, about **29.6%** or **131 schools** of them did not meet their target PARCC Math scores, according to NJ DOE.
#
# **291 schools** or about **65.8%** of schools either met their PARCC Math score targets or met their PARCC Math score targets within a confidence interval.
#
# **Note:** An "*" indicates that data is not displayed to protect student privacy; "N" indicates no data is available to display

# %% [markdown]
# ## How did these Schools Score in Language Arts?

# %%
met_target_ela = slow_internet_schools_all_joins.groupby( [ "MetTarget_ELA"] ).count()
met_target_ela = met_target_ela[['School Code']]
met_target_ela.reset_index()
met_target_ela['Percent'] = (met_target_ela['School Code']/slow_schools)*100
met_target_ela.reset_index()
# Out:
#   MetTarget_ELA  School Code    Percent
# 0            **            2   0.452489
# 1      Met Goal           15   3.393665
# 2    Met Target          225  50.904977
# 3   Met Target†          116  26.244344
# 4             N           10   2.262443
# 5       Not Met           73  16.515837

# %% [markdown]
# Out all of these 442 schools with less than 100 kpbs internet speeds, about **16.5%** or **73 schools** of them did not meet their target PARCC English Langauge Arts scores, according to NJ DOE.
#
# **341 schools** or about **77.3%** of schools either met their PARCC ELA score targets or met their PARCC ELA score targets within a confidence interval.
#
# **Note:** An "*" indicates that data is not displayed to protect student privacy; "N" indicates no data is available to display

# %% [markdown]
# ## Racial Breakdown
#
# ### How many are majority minority (less than 50 percent white)?

# %%
percent_majority_minority = slow_internet_schools_all_joins[slow_internet_schools_all_joins['Percent_white'] <= 50]

# %%
num_majority_minority = len(percent_majority_minority.index)
num_majority_minority
# Out:
# 277

# %%
pct_majority_minority = (float(num_majority_minority)/float(slow_schools))*100
pct_majority_minority
# Out:
# 62.66968325791855

# %% [markdown]
# About **62.7%** or **277** schools are majority minority, as in more than 50 percent of the students are non-white.

# %% [markdown]
# ### How many are majority black (more than 50 percent black)?

# %%
percent_majority_blck = slow_internet_schools_all_joins[slow_internet_schools_all_joins['Percent_blck'] > 50]

# %%
num_majority_blck = len(percent_majority_blck.index)
num_majority_blck
# Out:
# 94

# %%
pct_majority_blck = (float(num_majority_blck)/float(slow_schools))*100
pct_majority_blck
# Out:
# 21.266968325791854

# %% [markdown]
# About **21.3%** or **94** schools are majority Black, as in more than 50 percent of the students are Black.

# %% [markdown]
# #### How many are majority Hispanic (more than 50 percent Hispanic/Latino origin)?

# %%
percent_majority_hisp = slow_internet_schools_all_joins[slow_internet_schools_all_joins['Percent_hisp'] > 50]

# %%
num_majority_hisp = len(percent_majority_hisp.index)
num_majority_hisp
# Out:
# 135

# %%
pct_majority_hisp = (float(num_majority_hisp)/float(slow_schools))*100
pct_majority_hisp
# Out:
# 30.542986425339368

# %% [markdown]
# About **30.5%** or **135** schools are majority Hispanic, as in more than 50 percent of the students are Hispanic.

# %% [markdown]
# #### How many are majority Asian (more than 50 percent Asian)?

# %%
percent_majority_asian = slow_internet_schools_all_joins[slow_internet_schools_all_joins['Percent_asian'] > 50]

# %%
num_majority_asian = len(percent_majority_asian.index)
num_majority_asian
# Out:
# 0

# %% [markdown]
# None of the schools are more than 50 percent Asian.

# %% [markdown]
# ## Economic Disadvantage Breakdown

# %% [markdown]
# #### How many schools have a majority of students at an economic disadvantage (more than 50 percent)?

# %%
percent_majority_econdis = slow_internet_schools_all_joins[slow_internet_schools_all_joins['Percent_econdis'] > 50]

# %%
num_majority_econdis = len(percent_majority_econdis.index)
num_majority_econdis
# Out:
# 254

# %%
pct_majority_econdis = (float(num_majority_econdis)/float(slow_schools))*100
pct_majority_econdis
# Out:
# 57.466063348416284

# %% [markdown]
# About **57.5** or **254** schools have the majority of their students at an economic disadvantage, as in more than 50 percent of the students are Hispanic.
